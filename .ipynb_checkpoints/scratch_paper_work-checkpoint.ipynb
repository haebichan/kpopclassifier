# %%
import spotipy
import pandas as pd

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

my_id = '655e62800e724511b9a6f74b1bfa635f'
secret_key = '9e1f1feb45874771b24d1d10d19e87bd'

client_credentials_manager = SpotifyClientCredentials(client_id = my_id, client_secret = secret_key)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)



audiofeatures = sp.audio_features(tracks= ['https://open.spotify.com/track/03iCbZaM4OkRR4We6wIzvx'])

# %%
redvelvet = 'https://open.spotify.com/artist/1z4g3DjTBBZKhvAroFlhOM'
twentyone = 'https://open.spotify.com/artist/1l0mKo96Jh9HVYONcRl3Yp'
ikon = 'https://open.spotify.com/artist/5qRSs6mvI17zrkJpOHkCoM'
superjunior = 'https://open.spotify.com/artist/5qRSs6mvI17zrkJpOHkCoM'
gfriend = 'https://open.spotify.com/artist/0qlWcS66ohOIi0M8JZwPft'
wannaone = 'https://open.spotify.com/artist/2CvaqAMMsX576VBehaJ0Wx'
bts = 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'
bigbang = 'https://open.spotify.com/artist/4Kxlr1PRlDKEB0ekOCyHgX'
gg = 'https://open.spotify.com/artist/0Sadg1vgvaPqGTOjxu0N6c'
exo = 'https://open.spotify.com/artist/3cjEqqelV9zb4BYE3qDQ4O'
twice = 'https://open.spotify.com/artist/7n2Ycct7Beij7Dj7meI4X0'
blackpink = 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'
shinee = 'https://open.spotify.com/artist/2hRQKC0gqlZGPrmUKbcchR'

btob = 'https://open.spotify.com/artist/2hcsKca6hCfFMwwdbFvenJ'
aoa = 'https://open.spotify.com/artist/54gWVQFHf8IIqbjxAoOarN'
lovelyz = 'https://open.spotify.com/artist/3g34PW5oNmDBxMVUTzx2XK'

onedirection = 'https://open.spotify.com/artist/4AK6F7OLvEQ5QYCBNiQWHq'
# justinbieber = 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'
kellyclarkson = 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'
backstreetboys = 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'
nsync = 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'
arianagrande = 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'
ladygaga = 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'
brunomars = 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'
theweeknd = 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'

# %%
artist_list = [kellyclarkson]


feature_list = []

for artist in artist_list:
    
    artistalbums = sp.artist_albums(artist_id = artist, limit = 50)


    # go to their individual albums
    for i in range(len(artistalbums['items'])):
        album_uri = artistalbums['items'][i]['uri']
        album_tracks = sp.album_tracks(album_uri)
        
        #go to their individual tracks
        for j in range(len(album_tracks['items'])):
            album_song = album_tracks['items'][j]['uri']
            audiofeatures = sp.audio_features(album_song)
            
            #extract individual audio features of individual tracks
            for feature in audiofeatures:
                feature_list.append([feature['danceability'], feature['energy'], feature['key'], feature['speechiness'], 
                                     feature['acousticness'], feature['instrumentalness'], feature['liveness'], feature['valence'], 
                                     feature['tempo'], feature['duration_ms'],feature['time_signature'], artistalbums['items'][0]['artists'][0]['name']])

# %%
data = pd.DataFrame(feature_list, columns = ['danceability','energy','key','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms','time_signature', 'artist_name'])

# %%
artistalbums = sp.artist_albums(artist_id = redvelvet, limit = 50)

album_uri = artistalbums['items'][0]['uri']
album_tracks = sp.album_tracks(album_uri)

for j in range(len(album_tracks['items'])):
    title = album_tracks['items'][j]['name']
    print(title)
#         name = title.split()
#         name_list = []
#         for word in name:
#             if word.isalnum() and dictionary.check(word) == True:
#                 print(word)


# album_song = album_tracks['items'][0]['uri']
# audiofeatures = sp.audio_features(album_song)

# title = album_tracks['items'][0]['name']
# name = title.split()
# name_list = []
# for word in name:
#     if word.isalnum() and dictionary.check(word) == True:
#         print(word)
# Out:
# Bad Boy
# All Right
# 피카부 Peek-A-Boo
# 봐 Look
# I Just
# Kingdom Come
# Time To Love
# 두 번째 데이트 My Second Date
# Attaboy
# Perfect 10
# About Love
# 달빛 소리 Moonlight Melody

# %%
for title in album_tracks['items'][0]['name']:
    name = title.split()
    name_list = []
    for word in name:
        if word.isalnum() and dictionary.check(word) == True:
            print(word)
# Out:
# B
# a
# d
# B
# o
# y

# %%
album_tracks['items'][0]['name']
# Out:
# 'Bad Boy'

# %%
for i in range(len(artistalbums['items'])):
    print(artistalbums['items'][i]['release_date'])
# Out:
# 2017-10-27
# 2016-03-04
# 2016-03-04
# 2015-03-25
# 2015-02-27
# 2015-02-24
# 2013-10-29
# 2013-10-25
# 2012-11-19
# 2012-11-16
# 2011-10-26
# 2011-10-24
# 2011-10-24
# 2011-10-21
# 2011
# 2009-03-25
# 2009-03-06
# 2009-03-05
# 2007-07-31
# 2007-06-22
# 2007-06-20
# 2007
# 2005-07-16
# 2004-01-17
# 2004
# 2004
# 2003-09-29
# 2003-09-29
# 2003-07-23
# 2003-04-15
# 2018-07-27
# 2018-03-23
# 2018-03-08
# 2018-02-09
# 2017-11-29
# 2017-11-08
# 2017-10-25
# 2017-10-25
# 2017-10-25
# 2017-10-25
# 2017-10-18
# 2017-10-06
# 2017-10-06
# 2016-12-09
# 2016-11-04
# 2016-11-03
# 2016-11-03
# 2016-11-03
# 2016-11-03
# 2016-11-03

# %%
artistalbums['items'][]['release_date']
# Out:
# '2016-03-04'

# %%
artist_list = [onedirection, justinbieber]

artistalbums = sp.artist_albums(artist_id = justinbieber, limit = 50)

album_uri = artistalbums['items'][0]['uri']
album_tracks = sp.album_tracks(album_uri)

album_song = album_tracks['items'][0]['uri']
audiofeatures = sp.audio_features(album_song)

# %%
audiofeatures
# Out:
# [{'danceability': 0.416,
#   'energy': 0.258,
#   'key': 0,
#   'loudness': -8.489,
#   'mode': 1,
#   'speechiness': 0.0333,
#   'acousticness': 0.898,
#   'instrumentalness': 2.06e-06,
#   'liveness': 0.147,
#   'valence': 0.532,
#   'tempo': 116.599,
#   'type': 'audio_features',
#   'id': '2SnNaoNhMjC1WRMTWD8qTX',
#   'uri': 'spotify:track:2SnNaoNhMjC1WRMTWD8qTX',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SnNaoNhMjC1WRMTWD8qTX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SnNaoNhMjC1WRMTWD8qTX',
#   'duration_ms': 134347,
#   'time_signature': 4}]

# %%
feature_list
# Out:
# [[0.714,
#   0.736,
#   2,
#   0.0457,
#   0.191,
#   0,
#   0.0553,
#   0.814,
#   149.985,
#   210818,
#   4,
#   'Red Velvet'],
#  [0.777,
#   0.779,
#   9,
#   0.0427,
#   0.0417,
#   3.35e-06,
#   0.111,
#   0.774,
#   129.96,
#   207679,
#   4,
#   '2NE1']]

# %%
artistalbums['items'][0]['artists'][0]['name']
# Out:
# 'Red Velvet'

# %%
relatedartist = sp.artist_related_artists(artist_id= 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX')

# %%
# relatedartist

# %%
artistalbums = sp.artist_albums(artist_id='https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX', limit = 100)

# %%
feature_list = []

for iz in range(len(artistalbums['items'])):
    album_uri = artistalbums['items'][i]['uri']
    album_tracks = sp.album_tracks(album_uri)
    
    for j in range(len(album_tracks['items'])):
        album_song = album_tracks['items'][j]['uri']
        audiofeatures = sp.audio_features(album_song)
        
        for feature in audiofeatures:
            feature_list.append([feature['danceability'], feature['energy'], feature['key'], feature['speechiness'], feature['acousticness'], feature['instrumentalness'], feature['liveness'], feature['valence'], feature['tempo'], feature['duration_ms'],feature['time_signature']])

# %%
data = pd.DataFrame(feature_list, columns = ['danceability','energy','key','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms','time_signature'])

# %%
data.to_csv('bts_song_features.csv')

# %%
# for i in range(len(artistalbums['items'])):
#     album_uri = artistalbums['items'][i]['uri']
#     album_tracks = sp.album_tracks(album_uri)
    
#     for j in range(len(album_tracks['items'])):
#         album_song = album_tracks['items'][j]['uri']
#         audiofeatures = sp.audio_features(album_song)
        
#         for feature in audiofeatures:
#             print(feature)

# %%
redvelvet = 'https://open.spotify.com/artist/1z4g3DjTBBZKhvAroFlhOM'
twentyone = 'https://open.spotify.com/artist/1l0mKo96Jh9HVYONcRl3Yp'
ikon = 'https://open.spotify.com/artist/5qRSs6mvI17zrkJpOHkCoM'
superjunior = 'https://open.spotify.com/artist/5qRSs6mvI17zrkJpOHkCoM'
gfriend = 'https://open.spotify.com/artist/0qlWcS66ohOIi0M8JZwPft'
wannaone = 'https://open.spotify.com/artist/2CvaqAMMsX576VBehaJ0Wx'
bts = 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'
bigbang = 'https://open.spotify.com/artist/4Kxlr1PRlDKEB0ekOCyHgX'
gg = 'https://open.spotify.com/artist/0Sadg1vgvaPqGTOjxu0N6c'
exo = 'https://open.spotify.com/artist/3cjEqqelV9zb4BYE3qDQ4O'
twice = 'https://open.spotify.com/artist/7n2Ycct7Beij7Dj7meI4X0'
blackpink = 'https://open.spotify.com/artist/41MozSoPIsD1dJM0CLPjZF'
shinee = 'https://open.spotify.com/artist/2hRQKC0gqlZGPrmUKbcchR'

btob = 'https://open.spotify.com/artist/2hcsKca6hCfFMwwdbFvenJ'
aoa = 'https://open.spotify.com/artist/54gWVQFHf8IIqbjxAoOarN'
lovelyz = 'https://open.spotify.com/artist/3g34PW5oNmDBxMVUTzx2XK'
seventeen = 'https://open.spotify.com/artist/7nqOGRxlXj7N2JYbgNEjYH'

bts = 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'



dictionary = enchant.Dict("en_US")

albums = sp.artist_albums(artist_id = bigbang, limit = 50)

songs = []

for i in range(len(albums['items'])):
    album_uri = albums['items'][i]['uri']
    album_tracks = sp.album_tracks(album_uri)

    for j in range(len(album_tracks['items'])):
        album_song = album_tracks['items'][j]['name']
        songs.append(album_song)


global_list = []

for title in songs:
    j = title.split()
    local_list = []
    for word in j:
        if word.isalnum() and dictionary.check(word) == True:
            local_list.append(word.lower())

    global_list.append('-'.join(local_list))

# %%
dic = {'bts':'Bts','redvelvet':'red-velvet', 'twentyone':'2nse1', 'ikon': 'ikon', 'gfriend':'gfriend', 'wannaone':'wanna-one', 'bigbang':'big-bang', 'gg':'girls-generation','exo':'exo','twice':'twice','blackpink':'blackpink','shinee':'shinee', 'btob':'btob', 'aoa':'aoa', 'lovelyz':'lovelyz','seventeen':'seventeen'}

res = []

for i in range(len(global_list)):
    try:
        r = requests.get('https://genius.com/' + dic['seventeen'] + '-' + 'beautiful' + '-lyrics')
        soup = BeautifulSoup(r.text, 'lxml')
        lyrics = soup.find('div', class_='lyrics').get_text()
        if [global_list[i], lyrics] not in res:
            res.append([global_list[i], lyrics])
    except Exception as e:
        pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-ab61e240f031> in <module>()
#       5 for i in range(len(global_list)):
#       6     try:
# ----> 7         r = requests.get('https://genius.com/' + dic['seventeen'] + '-' + 'beautiful' + '-lyrics')
# ...

# %%
res[0]
# Out:
# ['euphoria',
#  "\n\n[방탄소년단의 Euphoria 가사]\n\n너는 내 삶에 다시 뜬 햇빛\n어린 시절 내 꿈들의 재림\n모르겠어 이 감정이 뭔지\n혹시 여기도 꿈속인 건지\n\n꿈은 사막의 푸른 신기루\n내 안 깊은 곳의 a priori\n숨이 막힐 듯이 행복해져\n주변이 점점 더 투명해져\n\n저기 멀리서 바다가 들려\n꿈을 건너서 수풀 너머로\n선명해지는 그 곳으로 가\nTake my hands now\nYou are the cause of my euphoria\n\nEuphoria\n\nTake my hands now\nYou are the cause of my euphoria\n\nEuphoria\n\nClose the door now\nWhen I'm with you I'm in utopia\n\n너도 나처럼\n지워진 꿈을 찾아 헤맸을까\n운명 같은 흔한 말관 달라\n아픈 너의 눈빛이 나와 같은 곳을 보는 걸\nWon't you please stay in dreams\n\n저기 멀리서 바다가 들려\n꿈을 건너서 수풀 너머로\n선명해지는 그곳으로 가\nTake my hands now\nYou are the cause of my euphoria\n\nEuphoria\n\nTake my hands now\nYou are the cause of my euphoria\n\n모래 바닥이 갈라진대도\n그 누가 이 세겔 흔들어도\n잡은 손 절대 놓지 말아 줘\n제발 꿈에서 깨어나지 마\n\n저기 멀리서 바다가 들려\n꿈을 건너서 수풀 너머로\n(제발 꿈에서 깨어나지 마)\n선명해지는 그곳으로 가\nTake my hands now\nYou are the cause of my euphoria\n\nEuphoria\n\nTake my hands now\nYou are the cause of my euphoria\n\nEuphoria\n\nClose the door now\nWhen I’m with you I’m in utopia\n\n"]

# %%
# df = pd.DataFrame(res).to_csv('lyrics_data/' + dic['seventeen'] + '_original_lyrics.csv')

# %% [markdown]
# # Beautiful Soup

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import nltk
from nltk.tokenize import *
from sklearn.cluster import *
from sklearn.model_selection import *
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

from scipy.cluster import *
from scipy.spatial import *


set_matplotlib_formats('retina')
# %pylab inline
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/Haebichan/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['Rectangle', 'load']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import enchant

dictionary = enchant.Dict("en_US")

# %%
redvelvet = 'https://open.spotify.com/artist/1z4g3DjTBBZKhvAroFlhOM'
twentyone = 'https://open.spotify.com/artist/1l0mKo96Jh9HVYONcRl3Yp'

# %%
dic = {'bts':'Bts','redvelvet':'red-velvet', 'twentyone':'2ne1', 'ikon': 'ikon', 'gfriend':'gfriend', 'wannaone':'wanna-one', 'bigbang':'big-bang', 'gg':'girls-generation','exo':'exo','twice':'twice','blackpink':'blackpink','shinee':'shinee', 'btob':'btob', 'aoa':'aoa', 'lovelyz':'lovelyz','seventeen':'seventeen'}

# %%
r = requests.get('https://genius.com/' + dic['seventeen'] + '-' + 'beautiful' + '-lyrics')
soup = BeautifulSoup(r.text, 'lxml')

# %%
lyrics  = soup.find('div', class_= 'lyrics').get_text()

# %%
search_list = ['Hangul','Korean']

for index in range(len(lyrics)):
    next_index = index + 1
    if any(substring in lyrics for substring in search_list):

#         while lyrics[next_index] not in search_list and next_index < len(lyrics) -1:
#             next_index +=1
#             english_lyrics = ' '.join(lyrics[index:next_index])    
            
english_lyrics
# Out:
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# haha
# ...

# %%
# def answer(k):
#     if 'English Translation'in k:
#         s = k.split('English Translation')

#         try:
#             j = ''.join(s[-1]).split('Original')
#             return j[0]
#         except Exception as e:
#             return s[-1]
#         else:
#             k = ''.join(s[-1]).split('Hangul')
#             return k[0]
#         finally:
#             l = ''.join(s[-1]).split('Romanized')
#             return l[0]

# answer(k) 

# #

# %%
s = k.split('English Translation')
j = ''.join(s).split('Korean Original')
print(j[0])
# Out:
# [Verse 1: Vernon]Yeah, UhThey’re like ocean wavesAm I going by the seasons, aloneAm I going by the seasons, aloneYup uhMan I’m livin' itEvery day is decentWherever I am all the kidsFollow around like ocean wavesWhen I’m switching the phone batteriesMessages are overflowing huhIt’s every day that I’m soaked in popularityBut my heart is about to wither[Pre-Chorus: Hoshi/Dino]As time goes byMy attitude towards everything is whateverI’m sick of trivial hangoutsAnd conversationsI don’t like having to live upTo other people’s expectationsAll of it just piles upAll the phone numbers I don’t callJust pile up, pile upIt piles up when I don’t want it to[Chorus: Woozi, DK]This cursed popularity. Why won’t it go awayBut why am I getting lonelierCold early morning wind Makes meEven more lonely todayI feel empty, Like I am empty[Post-Chorus: Jun, DK]Am I going by the seasons, aloneAm I going by the seasons, alone – Am I goingBy the seasons. Why am I talking to myself aloneI feel empty, Like I am e
# ...

# %%
artists = [redvelvet, twentyone]

all_song_names = []

for artist in artists:
    artistalbums = sp.artist_albums(artist_id = artist, limit = 50)

    artist_song_name = []
    
    for i in range(len(artistalbums['items'])):
        album_uri = artistalbums['items'][i]['uri']
        album_tracks = sp.album_tracks(album_uri)

        
        for j in range(len(album_tracks['items'])):
            album_song = album_tracks['items'][j]['name']

#             global_lyrics = []
#             for k in album_song:
#                 t = title.split()
#                 local_lyrics = []
#                 for word in t:
#                     if word.isalnum() and dictionary.check(word) == True:
#                         local_lyrics.append(word)
#                 global_lyrics.append('-'.join(local_lyrics))
        
                     
            artist_song_name.append(album_song.lower())
    

    
    all_song_names.append(artist_song_name)

# %%
final_list = []
for song_name in all_song_names:    
    
    global_list = []
    for title in song_name:
        local_list = []
        j = title.split()
        for word in j:
            if word.isalnum() and dictionary.check(word) == True:
                local_list.append(word.lower())


        global_list.append('-'.join(local_list))

    final_list.append(global_list)

# %%
from collections import OrderedDict
kpop_dic = OrderedDict({'redvelvet':'red-velvet', 'twentyone':'2ne1'})

# %%
for i in kpop_dic.keys():
    print(kpop_dic[i])
# Out:
# red-velvet
# 2ne1

# %%
global_res = []

for individual_list in final_list:
    for key in kpop_dic.keys():
        
        local_res = []

        for i in range(len(song_title)):
            try:
                r = requests.get('https://genius.com/Genius-translations-' + kpop_dic[key] + '-' + song_title[i] + '-english-translation-lyrics')
                soup = BeautifulSoup(r.text, 'lxml')
                lyrics = soup.find('div', class_='lyrics').get_text()
                local_res.append([song_title[i], lyrics])
            except Exception as e:
                pass 

        global_res.append(local_res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-254-467892715dbc> in <module>()
#       8         for i in range(len(song_title)):
#       9             try:
# ...

# %%
# final_list

# %%
r = requests.get('https://genius.com/Genius-translations-bts-euphoria-english-translation-lyrics')

# %%
# bts = 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'
exo = 'https://open.spotify.com/artist/3cjEqqelV9zb4BYE3qDQ4O'



bts_songs = []

btsalbums = sp.artist_albums(artist_id = exo, limit = 50)

for i in range(len(btsalbums['items'])):
    album_uri = btsalbums['items'][i]['uri']
    album_tracks = sp.album_tracks(album_uri)
    
    for j in range(len(album_tracks['items'])):
        album_song = album_tracks['items'][j]['name']
        bts_songs.append(album_song)

# %%
bts_songs = [i.lower() for i in bts_songs]

# %%
global_bts = []

for title in bts_songs:
    j = title.split()
    local_bts = []
    for word in j:
        if word.isalnum() and dictionary.check(word) == True:
            local_bts.append(word.lower())
#             print(word)
    global_bts.append('-'.join(local_bts))

# %%
def create_and_store_lyrics(sp, artist_name = None, artist_dic = None):
    # this is for scraping genius.com

    dictionary = enchant.Dict("en_US")

    albums = sp.artist_albums(artist_id = artist_name, limit = 50)

    songs = []

    for i in range(len(albums['items'])):
        album_uri = albums['items'][i]['uri']
        album_tracks = sp.album_tracks(album_uri)

        for j in range(len(album_tracks['items'])):
            album_song = album_tracks['items'][j]['name']
            songs.append(album_song)


    global_list = []

    for title in songs:
        j = title.split()
        local_list = []
        for word in j:
            if word.isalnum() and dictionary.check(word) == True:
                local_list.append(word.lower())

        global_list.append('-'.join(local_list))

    res = []

    for i in range(len(global_list)):
        try:
            r = requests.get('https://genius.com/Genius-translations-' + dic[artist_dic] + '-' + global_list[i] + '-english-translation-lyrics')
            soup = BeautifulSoup(r.text, 'lxml')
            lyrics = soup.find('div', class_='lyrics').get_text()
            res.append([global_list[i], lyrics])
        except Exception as e:
            r = requests.get('https://genius.com/' + dic['aoa'].title() + '-' + global_list[i] + '-lyrics')
            soup = BeautifulSoup(r.text, 'lxml')
            try:
                lyrics = soup.find('div', class_='lyrics').get_text()
                res.append([global_list[i], lyrics])
            except Exception as e:
                pass
            
    return res

# %%
res = create_and_store_lyrics(sp, artist_name = btob, artist_dic = 'btob')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-17f374add807> in <module>()
# ----> 1 res = create_and_store_lyrics(sp, artist_name = btob, artist_dic = 'btob')
#
# <ipython-input-72-3a717876fe5f> in create_and_store_lyrics(sp, artist_name, artist_dic)
# ...

# %%
pd.DataFrame(res)
# Out:
#            0                                                  1
# 0  energetic  \n\nYour lips and my lips\nI can feel it more ...
# 1  energetic  \n\nYour lips and my lips\nI can feel it more ...
# 2  energetic  \n\nYour lips and my lips\nI can feel it more ...
# 3  energetic  \n\nYour lips and my lips\nI can feel it more ...

# %%
# k = []

# for i in res:
#     if i:
#         k.append(i)

# %%
# pd.DataFrame(res)

# %%
dic = {'redvelvet':'red-velvet', 'twentyone':'2ne1', 'ikon': 'ikon', 'gfriend':'gfriend', 'wannaone':'wanna-one', 'bigbang':'big-bang', 'gg':'girls-generation','exo':'exo','twice':'twice','blackpink':'blackpink','shinee':'shinee', 'btob':'btob', 'aoa':'aoa', 'lovelyz':'lovelyz'}

# %%
dic['aoa']
# Out:
# 'aoa'

# %%
'https://genius.com/' + dic['aoa'].title() + '-' + k[0] + '-lyrics'
# Out:
# 'https://genius.com/Aoa-excuse-me-lyrics'

# %%
r = requests.get('https://genius.com/' + dic['aoa'].title() + '-' + k[0] + '-lyrics')
soup = BeautifulSoup(r.text, 'lxml')
lyrics = soup.find('div', class_='lyrics').get_text()

# %%
res = []

for i in range(len(global_list)):
    try:
        r = requests.get('https://genius.com/Genius-translations-' + dic[artist_dic] + '-' + global_list[i] + '-english-translation-lyrics')
        soup = BeautifulSoup(r.text, 'lxml')
        lyrics = soup.find('div', class_='lyrics').get_text()
        res.append([global_list[i], lyrics])
    except Exception as e:

# %%
# create_and_store_lyrics(sp, artist_name = shinee, artist_dic = 'shinee')

# %%
create_and_store_lyrics(sp, artist_name = wannaone, artist_dic = 'wannaone')

# %%
# r = requests.get('https://www.kpopviral.com/lyrics/exo-call-me-baby-lyrics-translation-english-romanized.html')

# %%
soup = BeautifulSoup(r.text, 'lxml')

# %%
import enchant
import requests
from bs4 import BeautifulSoup

dictionary = enchant.Dict("en_US")

def create_and_store_lyrics2(sp, artist_name = None, artist_dic = None):
    # this is using kpopviral.com for webscraping

    dictionary = enchant.Dict("en_US")
    
    albums = sp.artist_albums(artist_id = artist_name, limit = 50)
    
    songs = []
    
    for i in range(len(albums['items'])):
        album_uri = albums['items'][i]['uri']
        album_tracks = sp.album_tracks(album_uri)
        
        for j in range(len(album_tracks['items'])):
            album_song = album_tracks['items'][j]['name']
            songs.append(album_song)

    global_list = []

    for title in songs:
        j = title.split()
        local_list = []
        for word in j:
            if word.isalnum() and dictionary.check(word) == True:
                local_list.append(word.lower())
            
            global_list.append('-'.join(local_list))

    res = []

    for i in range(len(global_list)):
        try:
            r = requests.get('https://www.kpopviral.com/lyrics/' + dic[artist_dic] + '-' + global_list[i] + '-lyrics-translation-english-romanized.html')
            soup = BeautifulSoup(r.text, 'lxml')
            lyrics = soup.find('div', id = 'EnglishTranslation-0').get_text(strip = False)
            res.append([global_list[i], lyrics])
        except Exception as e:
            pass
        
    return res

# %%
res = create_and_store_lyrics2(sp, artist_name = wannaone, artist_dic = 'wannaone')

# %%
'https://www.kpopviral.com/lyrics/' + dic['bigbang'] + '-' +'bad-boy'+ '-lyrics-translation-english-romanized.html'
# Out:
# 'https://www.kpopviral.com/lyrics/bigbang-bad-boy-lyrics-translation-english-romanized.html'

# %%
r = requests.get('https://www.kpopviral.com/lyrics/' + dic['bigbang'] + '-' +'loser'+ '-lyrics-translation-english-romanized.html')

soup = BeautifulSoup(r.text, 'lxml')
lyrics = soup.find('div', id = 'EnglishTranslation-0').get_text(strip = False)

# %%
'https://www.kpopviral.com/lyrics/big-bang-loser-lyrics-translation-bigbang-english-romanized.html'
# Out:
# 'https://www.kpopviral.com/lyrics/big-bang-loser-lyrics-translation-bigbang-english-romanized.html'

# %%
'https://www.kpopviral.com/lyrics/bigbang-loser-lyrics-english-romanized.html'
# Out:
# 'https://www.kpopviral.com/lyrics/bigbang-loser-lyrics-english-romanized.html'

# %%
global_list[100]
# Out:
# 'last-dance-kr-special-event-2017'

# %%
# res

# %%
albums = sp.artist_albums(artist_id = bigbang, limit = 50)

songs = []

for i in range(len(albums['items'])):
    album_uri = albums['items'][i]['uri']
    album_tracks = sp.album_tracks(album_uri)
    
    for j in range(len(album_tracks['items'])):
        album_song = album_tracks['items'][j]['name']
        songs.append(album_song)

global_list = []

for title in songs:
    j = title.split()
    local_list = []
    for word in j:
        if word.isalnum() and dictionary.check(word) == True:
            local_list.append(word.lower())
        
    global_list.append('-'.join(local_list))

# %%
r = requests.get('https://www.kpopviral.com/lyrics/' + dic['bigbang'] + '-' + global_list[0] + '-lyrics-translation-english-romanized.html')

# %%
k = []

# %%
soup = BeautifulSoup(r.text, 'lxml')
lyrics = soup.find('div', id = 'EnglishTranslation-0').get_text(strip = False)
k.append([global_list[0], lyrics])

# %%
k
# Out:
# [['hands-up-japan-dome-tour-2017-the-final',
# ...

# %%
res = []

for i in range(len(global_list)):
    try:
        r = requests.get('https://genius.com/Genius-translations-' + dic['redvelvet'] + '-' + global_list[i] + '-english-translation-lyrics')
        soup = BeautifulSoup(r.text, 'lxml')
        lyrics = soup.find('div', class_='lyrics').get_text()
        res.append([global_list[i], lyrics])
    except Exception as e:
        pass

# %%
r = requests.get('https://genius.com/Genius-translations-' + dic['redvelvet'] + '-' + global_list[0] + '-english-translation-lyrics')

# %%
dic['redvelvet']
# Out:
# 'red-velvet'

# %%
r = requests.get('https://genius.com/Genius-translations-' + dic[redvelvet] + '-' + songs[0] + '-english-translation-lyrics')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-271-a3cd93df3b62> in <module>()
# ----> 1 r = requests.get('https://genius.com/Genius-translations-' + dic[redvelvet] + '-' + songs[0] + '-english-translation-lyrics')
#
# KeyError: 'https://open.spotify.com/artist/1z4g3DjTBBZKhvAroFlhOM'

# %%
songs[0]
# Out:
# 'bad boy'

# %%
dic[redvelvet]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-261-6e9d9b5becef> in <module>()
# ----> 1 dic[redvelvet]
#
# KeyError: 'https://open.spotify.com/artist/1z4g3DjTBBZKhvAroFlhOM'

# %%
def create_and_store_lyrics(sp, artist_name = redvelvet, artist_dic = 'redvelvet'):

    dictionary = enchant.Dict("en_US")


    albums = sp.artist_albums(artist_id = artist_name, limit = 50)


    songs = []

    for i in range(len(albums['items'])):
        album_uri = albums['items'][i]['uri']
        album_tracks = sp.album_tracks(album_uri)

        for j in range(len(album_tracks['items'])):
            album_song = album_tracks['items'][j]['name']
            songs.append(album_song)


    global_list = []

    for title in songs:
        j = title.split()
        local_list = []
        for word in j:
            if word.isalnum() and dictionary.check(word) == True:
                local_list.append(word.lower())

        global_list.append('-'.join(local_list))

    res = []

    for i in range(len(global_list)):
        try:
            r = requests.get('https://genius.com/Genius-translations-' + dic['redvelvet'] + '-' + global_list[i] + '-english-translation-lyrics')
            soup = BeautifulSoup(r.text, 'lxml')
            lyrics = soup.find('div', class_='lyrics').get_text()
            res.append([global_list[i], lyrics])
        except Exception as e:
            pass 


    df = pd.DataFrame(res)
    
    df.columns = ['name','text']

    df['text'] = df['text'].apply(lambda x: x.replace('\n', ' '))
w
    return df

# 	df.to_csv(dic[artist_dic] + '_translated_lyrics.csv')

# %%
soup.find('div', class_='lyrics').get_text()
# Out:
# "\n\nYou’re the sun that rose again in my life\nA reincarnation of my childhood dreams\nI don’t know what these emotions are\nAm I still dreaming?\n\nThis dream is a blue mirage in the desert\nA priori deep inside of me\nI’m so happy, I can’t breathe\nMy surroundings are getting more and more transparent\n\nI hear the far-away ocean\nAcross the dream, over the horizon\nI’m going to the place that’s getting clearer\nTake my hands now\nYou are the cause of my euphoria\n\nEuphoria\nTake my hands now\nYou are the cause of my euphoria\nEuphoria\nClose the door now\nWhen I’m with you I’m in utopia\n\nWere you wandering around\nLooking for an erased dream too?\nIt’s different from the typical definition of destiny\nYour pained eyes are looking at the same place as me\nWon't you please stay in dreams\n\nI hear the ocean from far away\nAcross the dream, over the horizon\nI’m going to the place that’s getting clearer\nTake my hands now\nYou are the cause of my euphoria\n\nEuphoria\nTake my han
# ...

# %%
res = []

for i in range(len(song_title)):
    try:
        r = requests.get('https://genius.com/Genius-translations-bts-' + song_title[i] + '-english-translation-lyrics')
        soup = BeautifulSoup(r.text, 'lxml')
        lyrics = soup.find('div', class_='lyrics').get_text()
        res.append([song_title[i], lyrics])
    except Exception as e:
        pass

# %%
pd.DataFrame(res).to_csv('BTS_translated_lyrics.csv')

# %%
lyrics = pd.DataFrame(res)

# %%
import string

# %%
lyrics[1] = lyrics[1].apply(lambda x: x.replace('\n', ' '))

# %%
lyrics[1][0]
# Out:
# "  You’re the sun that rose again in my life A reincarnation of my childhood dreams I don’t know what these emotions are Am I still dreaming?  This dream is a blue mirage in the desert A priori deep inside of me I’m so happy, I can’t breathe My surroundings are getting more and more transparent  I hear the far-away ocean Across the dream, over the horizon I’m going to the place that’s getting clearer Take my hands now You are the cause of my euphoria  Euphoria Take my hands now You are the cause of my euphoria Euphoria Close the door now When I’m with you I’m in utopia  Were you wandering around Looking for an erased dream too? It’s different from the typical definition of destiny Your pained eyes are looking at the same place as me Won't you please stay in dreams  I hear the ocean from far away Across the dream, over the horizon I’m going to the place that’s getting clearer Take my hands now You are the cause of my euphoria  Euphoria Take my hands now You are the cause of my euphori
# ...

# %%
lyrics[1]
# Out:
# 0        You’re the sun that rose again in my life A ...
# 1        If you ask me about that moment Bright sunsh...
# 2        [Verse 1: V, Jimin] You hide but only appear...
# 3        Is this love Is this love Sometimes I know S...
# 4        The world is a complex We wus lookin' for lo...
# 5        [Verse 1] A sound of something breaking I aw...
# 6        [Intro: V, Jungkook] For you, I could preten...
# 7        [Verse 1: V] Full of loneliness This garden ...
# 8        It was a good start In itself Before I knew ...
# 9        [Verse 1: RM] Goodbyes are, for me, a tear W...
# 10       [Verse 1] So weird, I for sure loved you so ...
# 11       [Verse 1: RM, J-Hope] You can call me artist...
# 12       [Verse 1: Jimin, Jungkook] I’m opening my ey...
# 13       [Verse 1: V, Jungkook] I know that you’re he...
# 14       [Intro: Jimin, Jungkook] When you say that y...
# 15       [Verse 1: RM, J-Hope] You can call me artist...
# ...

# %%
artistalbums['items'][0]['uri']
# Out:
# 'spotify:album:2lATw9ZAVp7ILQcOKPCPqp'

# %%
for i in range(artistalbums['items'])

# %%
audiofeatures[0]
# Out:
# {'danceability': 0.709,
#  'energy': 0.857,
#  'key': 9,
#  'loudness': -3.394,
#  'mode': 1,
#  'speechiness': 0.0881,
#  'acousticness': 0.00219,
#  'instrumentalness': 0,
#  'liveness': 0.103,
#  'valence': 0.446,
#  'tempo': 126.038,
#  'type': 'audio_features',
#  'id': '03iCbZaM4OkRR4We6wIzvx',
#  'uri': 'spotify:track:03iCbZaM4OkRR4We6wIzvx',
#  'track_href': 'https://api.spotify.com/v1/tracks/03iCbZaM4OkRR4We6wIzvx',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/03iCbZaM4OkRR4We6wIzvx',
#  'duration_ms': 260234,
#  'time_signature': 4}

# %%
album_tracks = sp.album_tracks(artistalbums['items'][0]['uri'])

l = []

for i in range(len(album_tracks['items'])):
    album_song = album_tracks['items'][i]['uri']
    audiofeatures = sp.audio_features(album_song)
    for feature in audiofeatures:
        l.append([feature['danceability'], feature['energy'], feature['key'], feature['speechiness'], feature['acousticness'], feature['instrumentalness'], feature['liveness'], feature['valence'], feature['tempo'], feature['duration_ms'],feature['time_signature']])

# %%
pd.DataFrame(l, columns = ['danceability','energy','key','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms','time_signature'])
# Out:
#     danceability  energy  key  speechiness  acousticness  instrumentalness  \
# 0          0.637   0.799    2       0.0338       0.39400          0.000000
# 1          0.723   0.906    1       0.2790       0.09070          0.000000
# 2          0.347   0.578    8       0.0626       0.44500          0.000000
# 3          0.599   0.774    1       0.0541       0.02230          0.000000
# 4          0.612   0.844    5       0.0756       0.14200          0.000000
# 5          0.761   0.761    5       0.0897       0.24600          0.000000
# 6          0.481   0.927    3       0.2700       0.31700          0.000000
# 7          0.775   0.271    1       0.0920       0.55400          0.002850
# 8          0.557   0.719    2       0.0372       0.00267          0.000000
# 9          0.570   0.422    1       0.0422       0.37200          0.000000
# 10         0.707   0.791    5       0.0350       0.18100          0.000000
# ...

# %%
data
# Out:
#    acousticness                                       analysis_url  \
# 0       0.00219  https://api.spotify.com/v1/audio-analysis/03iC...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.709       260234   0.857  03iCbZaM4OkRR4We6wIzvx
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0                 0    9     0.103    -3.394     1       0.0881  126.038
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/03iCbZaM4OkR...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:03iCbZaM4OkRR4We6wIzvx    0.446

# %%
len(album_tracks['items'])
# Out:
# 26

# %%
album_song = album_tracks['items'][25]['uri']

# %%
audiofeatures = sp.audio_features(album_song)

# %%
audiofeatures[0]
# Out:
# {'danceability': 0.637,
#  'energy': 0.799,
#  'key': 2,
#  'loudness': -4.519,
#  'mode': 1,
#  'speechiness': 0.0338,
#  'acousticness': 0.394,
#  'instrumentalness': 0,
#  'liveness': 0.0921,
#  'valence': 0.562,
#  'tempo': 104.995,
#  'type': 'audio_features',
#  'id': '3p6hnejEQYXkiTO1lAzVc0',
#  'uri': 'spotify:track:3p6hnejEQYXkiTO1lAzVc0',
#  'track_href': 'https://api.spotify.com/v1/tracks/3p6hnejEQYXkiTO1lAzVc0',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3p6hnejEQYXkiTO1lAzVc0',
#  'duration_ms': 228615,
#  'time_signature': 4}

# %%
pd.DataFrame.from_dict(audiofeatures)
# Out:
#    acousticness                                       analysis_url  \
# 0       0.00219  https://api.spotify.com/v1/audio-analysis/03iC...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.709       260234   0.857  03iCbZaM4OkRR4We6wIzvx
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0                 0    9     0.103    -3.394     1       0.0881  126.038
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/03iCbZaM4OkR...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:03iCbZaM4OkRR4We6wIzvx    0.446

# %%
audioanalysis = sp.audio_analysis(id = 'https://open.spotify.com/track/03iCbZaM4OkRR4We6wIzvx')

# %%
# audioanalysis['track']

# %%
albums = sp.album(album_id='https://open.spotify.com/album/2lATw9ZAVp7ILQcOKPCPqp')

# %%
albums
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#    'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#    'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#    'name': 'BTS',
#    'type': 'artist',
#    'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#  'available_markets': ['AD',
#   'AR',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BO',
#   'BR',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'EC',
#   'EE',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IS',
#   'IT',
#   'JP',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MC',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'PY',
#   'RO',
#   'SE',
#   'SG',
#   'SK',
#   'SV',
#   'TH',
#   'TR',
#   'TW',
#   'US',
#   'UY',
#   'VN',
# ...

# %%
albumtracks = sp.album_tracks(album_id = 'https://open.spotify.com/album/2jJfnAZE6IG3oYnUv2eCj4')

# %%
albumtracks
# Out:
# {'href': 'https://api.spotify.com/v1/albums/2jJfnAZE6IG3oYnUv2eCj4/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Nrfpe0tUJi4K4DXYWgMUX'},
#      'href': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX',
#      'id': '3Nrfpe0tUJi4K4DXYWgMUX',
#      'name': 'BTS',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
# ...
